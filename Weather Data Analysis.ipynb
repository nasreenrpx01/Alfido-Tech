# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Weather Data.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.isnull().value_counts
# Out:
# <bound method DataFrame.value_counts of       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# ...

# %%
df.isna()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
Weather= df['Weather'].unique()
for weather in Weather:
    print(weather)
# Out:
# Fog
# Freezing Drizzle,Fog
# Mostly Cloudy
# Cloudy
# Rain
# Rain Showers
# Mainly Clear
# Snow Showers
# Snow
# Clear
# Freezing Rain,Fog
# Freezing Rain
# Freezing Drizzle
# Rain,Snow
# Moderate Snow
# Freezing Drizzle,Snow
# Freezing Rain,Snow Grains
# Snow,Blowing Snow
# Freezing Fog
# Haze
# Rain,Fog
# Drizzle,Fog
# Drizzle
# Freezing Drizzle,Haze
# Freezing Rain,Haze
# Snow,Haze
# Snow,Fog
# Snow,Ice Pellets
# Rain,Haze
# Thunderstorms,Rain
# Thunderstorms,Rain Showers
# Thunderstorms,Heavy Rain Showers
# Thunderstorms,Rain Showers,Fog
# Thunderstorms
# Thunderstorms,Rain,Fog
# Thunderstorms,Moderate Rain Showers,Fog
# Rain Showers,Fog
# Rain Showers,Snow Showers
# Snow Pellets
# Rain,Snow,Fog
# Moderate Rain,Fog
# Freezing Rain,Ice Pellets,Fog
# Drizzle,Ice Pellets,Fog
# Drizzle,Snow
# Rain,Ice Pellets
# Drizzle,Snow,Fog
# Rain,Snow Grains
# Rain,Snow,Ice Pellets
# Snow Showers,Fog
# Moderate Snow,Blowing Snow

# %%
Foggy_days=df[df['Weather']=='Fog']
Foggy_days
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df['Weather'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object>

# %%
Clear_days=df[df['Weather']=='Clear']
Clear_days
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
Windy_days=df[df['Wind Speed_km/h']>20]
Windy_days
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 15      1/1/2012 15:00     1.8              -0.4         85               22
# 22      1/1/2012 22:00     4.4               1.9         84               24
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
Sunny_days = df[(df['Temp_C'] > 20) & (df['Weather'] == 'Clear')]
Sunny_days
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 1910   3/20/2012 14:00    21.5              11.8         54               11
# 1911   3/20/2012 15:00    22.5              12.3         52                9
# 1912   3/20/2012 16:00    23.3              12.1         49                7
# 1913   3/20/2012 17:00    22.0              12.1         53                7
# 1931   3/21/2012 11:00    20.2              12.3         60               15
# ...                ...     ...               ...        ...              ...
# 6255   9/17/2012 15:00    25.2              10.8         40               15
# 6257   9/17/2012 17:00    24.4              12.2         46               13
# 7189  10/26/2012 13:00    20.9              13.3         62               11
# 7190  10/26/2012 14:00    21.1              13.0         60                9
# 7191  10/26/2012 15:00    20.4              13.1         63               13
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
Rainy_days=df[df['Weather']=='Rain']
Rainy_days
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 18      1/1/2012 18:00     3.8               1.0         82               15
# 19      1/1/2012 19:00     3.1               1.3         88               15
# 542    1/23/2012 14:00     2.7              -1.1         76               26
# 543    1/23/2012 15:00     2.7              -0.9         77               30
# 545    1/23/2012 17:00     3.1              -0.4         78               28
# ...                ...     ...               ...        ...              ...
# 8537  12/21/2012 17:00     1.3               0.2         92               46
# 8538  12/21/2012 18:00     1.4               0.3         92               46
# 8539  12/21/2012 19:00     2.3               1.1         92               37
# 8540  12/21/2012 20:00     2.4               1.7         95               15
# 8541  12/21/2012 21:00     1.3               0.4         94               22
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Temp_C'], bins=20, color='green')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.title('Temperature Distribution')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Temp_C'], df['Wind Speed_km/h'], color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Wind Speed (km/h)')
plt.title('Temperature vs. Wind Speed')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date/Time'], df['Temp_C'], label='Temperature (°C)', color='blue')
plt.xlabel('Date/Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Over Time')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date/Time'], df['Dew Point Temp_C'], color='green')
plt.xlabel('Date/Time')
plt.ylabel('Dew Point Temperature (°C)')
plt.title('Dew Point Temperature Over Time')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date/Time', y='Wind Speed_km/h', data=df)
plt.title('Wind Speed Over Time')
plt.xlabel('Date/Time')
plt.ylabel('Wind Speed (km/h)')
plt.grid()
plt.show()
